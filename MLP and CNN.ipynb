# %% [markdown]
# Royston Rex Fernandez - 201759033 <br>
# Atshaya Srinivasan - 201774445

# %% [markdown]
# # Importing the libraries
# We import all of the essential libraries first for data loading, processing, model training and performance evaluation

# %%
# Basic libraries for data processing and visualisation
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Importing Tensorflow libraries for deep learning algorithms
import tensorflow as tf
from keras import regularizers
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization, Dropout, Activation
from keras.optimizers import SGD, Adam, Adagrad
from keras.optimizers.schedules import ExponentialDecay, InverseTimeDecay
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping


# Importing sci-kit learn packages for validation and evaluation
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, ConfusionMatrixDisplay

# Suppressing unwanted warnings
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# # Loading the dataset

# %%
# Load the EMNIST Balanced dataset using pandas
train_path = "emnist-balanced-train.csv"
test_path = "emnist-balanced-test.csv"

train_df = pd.read_csv(train_path, header=None)
test_df = pd.read_csv(test_path, header=None)

# Extract train and test data
x_train = train_df.iloc[:, 1:].values
x_test = test_df.iloc[:, 1:].values
y_train = train_df.iloc[:, 0].values
y_test = test_df.iloc[:, 0].values

# We encode the labels as one-hot encoding as the neural network has a softmax activation
one_hot_y_train = to_categorical(y_train, num_classes=47)
one_hot_y_test = to_categorical(y_test, num_classes=47)

# Normalize the pixel values to be between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape the images
x_train = x_train.reshape((-1, 28, 28, 1))
x_test = x_test.reshape((-1, 28, 28, 1))

# Print the number of training and testing samples
print(f"Number of training samples: {len(x_train)}")
print(f"Number of testing samples: {len(x_test)}")

# Read the mapping from the text file using pandas
class_mapping_file = "emnist-balanced-mapping.txt"
class_mapping_df = pd.read_csv(class_mapping_file, sep=' ', header=None, names=['Class Label', 'Character'])
class_mapping = dict(zip(class_mapping_df['Class Label'], class_mapping_df['Character']))
# Out:
# Number of training samples: 112800
# Number of testing samples: 18800

# %% [markdown]
# # Plotting the images

# %%
def plot_images(images, labels, class_mapping, num_images=10):
    """
    Plots a specified number of images along with their corresponding labels.

    Parameters:
        images (numpy.ndarray): Array of image data. Each image should be represented as a 1D array.
        labels (numpy.ndarray): Array of labels corresponding to the images.
        class_mapping (dict): A dictionary mapping label indices to their corresponding characters.
        num_images (int): Number of images to plot. Default is 10.

    Returns:
        None
    """
    # Generate random indices to select random samples
    indices = np.random.choice(len(images), num_images, replace=False)
    
    # Create subplots
    fig, axes = plt.subplots(1, num_images, figsize=(15, 3))
    
    # Plot each image and its corresponding label
    for i, idx in enumerate(indices):
        ax = axes[i]
        image = images[idx].reshape(28, 28)  # Reshape image to 28x28
        label_index = labels[idx]
        label = chr(class_mapping[label_index]) # Converts the ASCI mapping to characters
        ax.imshow(image, cmap='magma')
        ax.set_title(f"Label: {label}")
        ax.axis('off')
    plt.tight_layout()
    plt.show()
    
plot_images(x_train, y_train, class_mapping)

# %% [markdown]
# # Model Initialisation and Compilation
# ### Our first baseline model is created using the below parameters for both MLP and CNN:
#
# For MLP the base model has the below parameters:-
# 1) Activation function is ReLu
# 2) Optimizer is SGD
# 3) No batch Normalisation
# 4) Regularisation is None
# 5) No Dropout
# 6) No Learning Rate Scheduler
#
# For CNN the base model has the below parameters:-
# 1) Activation function is ReLu
# 2) Optimizer is AdaGrad
# 3) No batch Normalisation
# 4) Regularisation is None
# 5) No Dropout
# 6) Learning Rate Scheduler is Exponential Decay

# %%
# Base MLP Model
def create_mlp(num_classes,optimizer='sgd', activation='relu', 
               learning_rate_scheduler=None, regularizer=None,
               use_dropout=False, use_batch_norm=False):
    """
    Creates a Multi-Layer Perceptron (MLP) model with configurable options.

    Parameters:
        num_classes (int): Number of classes in the classification task.
        optimizer (str): Name of the optimizer to use. Options: 'adam', 'sgd', 'adagrad'. Default is 'adam'.
        activation (str): Activation function to use in hidden layers. Default is 'tanh'.
        learning_rate_scheduler (str): Learning rate scheduler type. Options: 'exp' (exponential), 'invdecay' (inverse decay), None (no scheduler). Default is None.
        regularizer (tensorflow.keras.regularizers.Regularizer): Regularization function. Default is None.
        use_dropout (bool): Whether to use dropout regularization. Default is False.
        use_batch_norm (bool): Whether to use batch normalization. Default is False.

    Returns:
        tensorflow.keras.models.Sequential: Compiled MLP model.
    """
    model = Sequential()
    # Flatten input layer
    model.add(Flatten(input_shape=x_train[0].shape)) 
    
    # Hidden layers 1
    model.add(Dense(128, kernel_regularizer=regularizer))
    if use_batch_norm:
        model.add(BatchNormalization())
    model.add(Activation(activation))
    if use_dropout:
        model.add(Dropout(0.2))
        
    # Hidden layers 2
    model.add(Dense(64, kernel_regularizer=regularizer))
    if use_batch_norm:
        model.add(BatchNormalization())
    model.add(Activation(activation))
    if use_dropout:
        model.add(Dropout(0.2))
    
    # Hidden layers 3
    model.add(Dense(64, kernel_regularizer=regularizer))
    if use_batch_norm:
        model.add(BatchNormalization())
    model.add(Activation(activation))
    if use_dropout:
        model.add(Dropout(0.2))

    # Ouput Layer
    model.add(Dense(num_classes, activation='softmax'))
    
    # Configure learning rate scheduler
    if learning_rate_scheduler == 'exp':
        learning_rate = ExponentialDecay(initial_learning_rate=0.01, decay_steps=10000, decay_rate=0.96)
    elif learning_rate_scheduler == 'invdecay':
        learning_rate = InverseTimeDecay(initial_learning_rate=0.01, decay_steps=10000, decay_rate=0.5)
    elif learning_rate_scheduler == None:
        learning_rate = 0.01
    
    # Configure optimizer
    if optimizer == 'sgd':
        optimizer = SGD(learning_rate=learning_rate)
    elif optimizer == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    elif optimizer == 'adagrad':
        optimizer = Adagrad(learning_rate=learning_rate)
    
    # Compile the model
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %%
def create_cnn(num_classes, optimizer='adagrad', activation='relu',
               learning_rate_scheduler='exp', regularizer=None,
               use_dropout=False, use_batch_norm=False):
    """
    Creates a Convolutional Neural Network (CNN) model with configurable options.

    Parameters:
        num_classes (int): Number of classes in the classification task.
        optimizer (str): Name of the optimizer to use. Options: 'adam', 'sgd', 'adagrad'. Default is 'adam'.
        activation (str): Activation function to use in convolutional and dense layers. Default is 'tanh'.
        learning_rate_scheduler (str): Learning rate scheduler type. Options: 'exp' (exponential), 'invdecay' (inverse decay), None (no scheduler). Default is 'exp'.
        regularizer (tensorflow.keras.regularizers.Regularizer): Regularization function. Default is None.
        use_dropout (bool): Whether to use dropout regularization. Default is False.
        use_batch_norm (bool): Whether to use batch normalization. Default is False.

    Returns:
        tensorflow.keras.models.Sequential: Compiled CNN model.
    """
    model = Sequential()
    
    # Convolutional layers 1
    model.add(Conv2D(32, kernel_size=(3, 3), kernel_regularizer=regularizer,input_shape=x_train[0].shape))
    if use_batch_norm:
        model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    if use_dropout:
        model.add(Dropout(0.25))
    
    # Convolutional layers 2
    model.add(Conv2D(64, kernel_size=(3, 3), kernel_regularizer=regularizer))
    if use_batch_norm:
        model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    if use_dropout:
        model.add(Dropout(0.25))
    
    # Fully connected layers
    model.add(Flatten())
    model.add(Dense(128, kernel_regularizer=regularizer))
    if use_batch_norm:
        model.add(BatchNormalization())
    model.add(Activation(activation))
    if use_dropout:
        model.add(Dropout(0.5))
    
    # Output Layer
    model.add(Dense(num_classes, activation='softmax'))
    
    # Configure learning rate scheduler
    if learning_rate_scheduler == 'exp':
        learning_rate = ExponentialDecay(initial_learning_rate=0.01, decay_steps=10000, decay_rate=0.96)
    elif learning_rate_scheduler == 'invdecay':
        learning_rate = InverseTimeDecay(initial_learning_rate=0.01, decay_steps=10000, decay_rate=0.5)
    elif learning_rate_scheduler == None:
        learning_rate = 0.01

    # Configure optimizer
    if optimizer == 'sgd':
        optimizer = SGD(learning_rate=learning_rate)
    elif optimizer == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    elif optimizer == 'adagrad':
        optimizer = Adagrad(learning_rate=learning_rate)
    
    # Compile the model
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %% [markdown]
# # MLP
# ## Model Training
# We then train our base MLP model on the training dataset and validate against a predefined validation set which is the last 20% of the training data.

# %%
# Build and Train MLP Model
mlp_base = create_mlp(num_classes=len(np.unique(y_train)))
mlp_base_history = mlp_base.fit(x_train, one_hot_y_train, epochs=10, batch_size=47, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 1920/1920 [==============================] - 8s 4ms/step - loss: 2.6979 - accuracy: 0.3130 - val_loss: 1.5342 - val_accuracy: 0.5687
# Epoch 2/10
# 1920/1920 [==============================] - 6s 3ms/step - loss: 1.3379 - accuracy: 0.6226 - val_loss: 1.1801 - val_accuracy: 0.6595
# Epoch 3/10
# 1920/1920 [==============================] - 7s 3ms/step - loss: 1.0980 - accuracy: 0.6829 - val_loss: 1.0252 - val_accuracy: 0.6953
# Epoch 4/10
# 1920/1920 [==============================] - 8s 4ms/step - loss: 0.9652 - accuracy: 0.7155 - val_loss: 0.9135 - val_accuracy: 0.7242
# Epoch 5/10
# 1920/1920 [==============================] - 7s 4ms/step - loss: 0.8733 - accuracy: 0.7386 - val_loss: 0.8470 - val_accuracy: 0.7430
# Epoch 6/10
# 1920/1920 [==============================] - 7s 4ms/step - loss: 0.8051 - accuracy: 0.7561 - val_loss: 0.7878 - val_accuracy: 0.7552
# Epoch 7/10
# 1920/1920 [==============================] - 7s 3ms/step - loss: 0.7524 - accuracy: 0.7694 - val_loss: 0.7439 - val_accuracy: 0.7664
# Epoch 8/10
# 1920/1920 [==============================] - 6s 3ms/step - loss: 0.7116 - accuracy: 0.7817 - val_loss: 0.7218 - val_accuracy: 0.7727
# Epoch 9/10
# 1920/1920 [==============================] - 7s 4ms/step - loss: 0.6774 - accuracy: 0.7904 - val_loss: 0.7069 - val_accuracy: 0.7774
# Epoch 10/10
# 1920/1920 [==============================] - 6s 3ms/step - loss: 0.6490 - accuracy: 0.7979 - val_loss: 0.6832 - val_accuracy: 0.7831

# %%
# Get validation accuracy and loss of the base model
final_mlp_val_accuracy = mlp_base_history.history['val_accuracy'][-1]
final_mlp_val_loss = mlp_base_history.history['val_loss'][-1]

print("Accuracy of Base MLP Model:", final_mlp_val_accuracy)
print("Loss of Base MLP Model:", final_mlp_val_loss)
# Out:
# Accuracy of Base MLP Model: 0.7831116914749146
# Loss of Base MLP Model: 0.6832437515258789

# %% [markdown]
# ## Exploring Different Hyperparameter Combinations
# Now we fine tune different hyperparameters to make our baseline model more efficient and accurate by exploring different techniques. We define a dictionary to store these parameters, so that the optimization function can iteratively fine tune our models. We then use a validation dataset to validate our training results to find the best parameters for our model.

# %%
# Tunable parameters
hyperparameter_dict = {
    "activation": ['relu', 'elu', 'tanh'],
    "optimizer": ['sgd', 'adam', 'adagrad'],
    "learning_rate_scheduler": ["exp", "invdecay"],
    'regularizer': [regularizers.l1(0.01), regularizers.l2(0.01), None],
    "use_dropout": [True, False],
    "use_batch_norm": [True, False],
}

# %% [markdown]
#  We use a strategy where we start with a baseline configuration and progressively refine the model through systematic investigation and evaluation of activation functions, optimizers, regularization methods, and learning rate scheduling while preserving the most effective settings from previous explorations.

# %%
def optimize_hyperparameters(hyperparameter_dict, x_train, one_hot_y_train, model_name):
    """
    Optimizes hyperparameters for a given model.

    Parameters:
        hyperparameter_dict (dict): Dictionary containing hyperparameters to tune and their respective values.
        x_train (numpy.ndarray): Training data.
        one_hot_y_train (numpy.ndarray): One-hot encoded labels for training data.
        model_name (str): Name of the model to optimize hyperparameters for. Options: 'mlp' or 'cnn'.

    Returns:
        tuple: A tuple containing the best hyperparameters and the corresponding best accuracy.
    """
    # Start the timer
    startTime = time.time()
    
    best_params = {}
    best_accuracy = 0  
    # Iterate through each hyperparameter in the grid
    for hyperparameter, values in hyperparameter_dict.items(): 
 
        for value in values:
            # Print loop progress
            print(f"Processing combination: {hyperparameter}={value}")
            val_accuracies = []
            
            if model_name == 'mlp':
                # Create and compile the MLP model with current hyperparameters
                model = create_mlp(num_classes=len(np.unique(y_train)), **best_params)
            elif model_name == 'cnn':
                # Create and compile the CNN model with current hyperparameters
                model = create_cnn(num_classes=len(np.unique(y_train)), **best_params)
            
            # Define EarlyStopping callback which monitors the validation loss
            early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
            
            # Train the model (consider using early stopping for efficiency)
            model_history = model.fit(x_train, one_hot_y_train, epochs=10, batch_size=47, validation_split=0.2, verbose=2, callbacks=[early_stopping])

            # Evaluate the model on validation set and calculate accuracy
            val_accuracy = model_history.history['val_accuracy'][-1]
            val_accuracies.append(val_accuracy)
            avg_val_accuracy = np.mean(val_accuracies)
            
            # Update best hyperparameters if current combination performs better
            if avg_val_accuracy > best_accuracy:
                best_accuracy = avg_val_accuracy
                # Update best_params only if current combination is better
                best_params = {**best_params, hyperparameter: value}  # Update with dictionary comprehension
        
        # Print the current best hyperparameter
        print(f"Best Accuracy of {hyperparameter}: {best_accuracy}")
        print(f"Best Hyperparameters:")
        for key, value in best_params.items():
            print(f"\t- {key}: {value}")

    # End the timer and compute the total training time
    endTime = time.time()
    trainingTime = endTime - startTime
    
    return best_params, best_accuracy, trainingTime

# %% [markdown]
# We now then train the model on the tunable hyperparameters to get the best MLP model

# %%
# Fine tuning the parameters
best_mlp_params, best_mlp_accuracy, time = optimize_hyperparameters(hyperparameter_dict, x_train, one_hot_y_train, model_name='mlp')
# Out:
# Processing combination: activation=relu
# Epoch 1/10
# 1920/1920 - 8s - loss: 2.7761 - accuracy: 0.2917 - val_loss: 1.6142 - val_accuracy: 0.5477 - 8s/epoch - 4ms/step
# Epoch 2/10
# 1920/1920 - 6s - loss: 1.3810 - accuracy: 0.6066 - val_loss: 1.2027 - val_accuracy: 0.6553 - 6s/epoch - 3ms/step
# Epoch 3/10
# 1920/1920 - 5s - loss: 1.1201 - accuracy: 0.6761 - val_loss: 1.0346 - val_accuracy: 0.6993 - 5s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 5s - loss: 0.9768 - accuracy: 0.7132 - val_loss: 0.9271 - val_accuracy: 0.7241 - 5s/epoch - 3ms/step
# Epoch 5/10
# 1920/1920 - 5s - loss: 0.8796 - accuracy: 0.7398 - val_loss: 0.8461 - val_accuracy: 0.7433 - 5s/epoch - 3ms/step
# Epoch 6/10
# 1920/1920 - 11s - loss: 0.8080 - accuracy: 0.7574 - val_loss: 0.7908 - val_accuracy: 0.7574 - 11s/epoch - 6ms/step
# Epoch 7/10
# 1920/1920 - 11s - loss: 0.7526 - accuracy: 0.7725 - val_loss: 0.7384 - val_accuracy: 0.7729 - 11s/epoch - 6ms/step
# Epoch 8/10
# 1920/1920 - 11s - loss: 0.7090 - accuracy: 0.7827 - val_loss: 0.7107 - val_accuracy: 0.7762 - 11s/epoch - 6ms/step
# Epoch 9/10
# 1920/1920 - 12s - loss: 0.6726 - accuracy: 0.7925 - val_loss: 0.6877 - val_accuracy: 0.7840 - 12s/epoch - 6ms/step
# Epoch 10/10
# 1920/1920 - 12s - loss: 0.6417 - accuracy: 0.8001 - val_loss: 0.6689 - val_accuracy: 0.7888 - 12s/epoch - 6ms/step
# Processing combination: activation=elu
# Epoch 1/10
# 1920/1920 - 13s - loss: 2.7575 - accuracy: 0.2948 - val_loss: 1.6375 - val_accuracy: 0.5392 - 13s/epoch - 7ms/step
# Epoch 2/10
# 1920/1920 - 12s - loss: 1.3913 - accuracy: 0.6078 - val_loss: 1.2275 - val_accuracy: 0.6436 - 12s/epoch - 6ms/step
# Epoch 3/10
# 1920/1920 - 12s - loss: 1.1270 - accuracy: 0.6747 - val_loss: 1.0471 - val_accuracy: 0.6908 - 12s/epoch - 6ms/step
# Epoch 4/10
# 1920/1920 - 11s - loss: 0.9772 - accuracy: 0.7124 - val_loss: 0.9180 - val_accuracy: 0.7240 - 11s/epoch - 6ms/step
# Epoch 5/10
# 1920/1920 - 11s - loss: 0.8736 - accuracy: 0.7383 - val_loss: 0.8554 - val_accuracy: 0.7378 - 11s/epoch - 6ms/step
# Epoch 6/10
# 1920/1920 - 11s - loss: 0.8000 - accuracy: 0.7595 - val_loss: 0.7848 - val_accuracy: 0.7563 - 11s/epoch - 6ms/step
# Epoch 7/10
# 1920/1920 - 12s - loss: 0.7466 - accuracy: 0.7731 - val_loss: 0.7523 - val_accuracy: 0.7660 - 12s/epoch - 6ms/step
# Epoch 8/10
# 1920/1920 - 12s - loss: 0.7043 - accuracy: 0.7841 - val_loss: 0.7186 - val_accuracy: 0.7762 - 12s/epoch - 6ms/step
# Epoch 9/10
# 1920/1920 - 12s - loss: 0.6703 - accuracy: 0.7914 - val_loss: 0.7108 - val_accuracy: 0.7747 - 12s/epoch - 6ms/step
# Epoch 10/10
# 1920/1920 - 12s - loss: 0.6419 - accuracy: 0.7994 - val_loss: 0.6821 - val_accuracy: 0.7804 - 12s/epoch - 6ms/step
# Processing combination: activation=tanh
# Epoch 1/10
# 1920/1920 - 13s - loss: 2.6545 - accuracy: 0.3215 - val_loss: 1.5643 - val_accuracy: 0.5613 - 13s/epoch - 7ms/step
# Epoch 2/10
# 1920/1920 - 11s - loss: 1.3529 - accuracy: 0.6149 - val_loss: 1.2041 - val_accuracy: 0.6517 - 11s/epoch - 6ms/step
# Epoch 3/10
# 1920/1920 - 12s - loss: 1.1065 - accuracy: 0.6801 - val_loss: 1.0269 - val_accuracy: 0.7003 - 12s/epoch - 6ms/step
# Epoch 4/10
# 1920/1920 - 12s - loss: 0.9636 - accuracy: 0.7155 - val_loss: 0.9104 - val_accuracy: 0.7259 - 12s/epoch - 6ms/step
# Epoch 5/10
# 1920/1920 - 11s - loss: 0.8634 - accuracy: 0.7418 - val_loss: 0.8432 - val_accuracy: 0.7415 - 11s/epoch - 6ms/step
# Epoch 6/10
# 1920/1920 - 8s - loss: 0.7904 - accuracy: 0.7611 - val_loss: 0.7884 - val_accuracy: 0.7571 - 8s/epoch - 4ms/step
# Epoch 7/10
# 1920/1920 - 6s - loss: 0.7348 - accuracy: 0.7750 - val_loss: 0.7350 - val_accuracy: 0.7707 - 6s/epoch - 3ms/step
# Epoch 8/10
# 1920/1920 - 6s - loss: 0.6910 - accuracy: 0.7856 - val_loss: 0.7021 - val_accuracy: 0.7764 - 6s/epoch - 3ms/step
# Epoch 9/10
# 1920/1920 - 6s - loss: 0.6550 - accuracy: 0.7959 - val_loss: 0.6815 - val_accuracy: 0.7841 - 6s/epoch - 3ms/step
# Epoch 10/10
# 1920/1920 - 5s - loss: 0.6267 - accuracy: 0.8033 - val_loss: 0.6561 - val_accuracy: 0.7915 - 5s/epoch - 3ms/step
# Best Accuracy of activation: 0.7914893627166748
# Best Hyperparameters:
# 	- activation: tanh
# Processing combination: optimizer=sgd
# Epoch 1/10
# 1920/1920 - 6s - loss: 2.6272 - accuracy: 0.3801 - val_loss: 1.9150 - val_accuracy: 0.5351 - 6s/epoch - 3ms/step
# Epoch 2/10
# 1920/1920 - 7s - loss: 1.6493 - accuracy: 0.5834 - val_loss: 1.4516 - val_accuracy: 0.6156 - 7s/epoch - 4ms/step
# Epoch 3/10
# 1920/1920 - 6s - loss: 1.3455 - accuracy: 0.6411 - val_loss: 1.2480 - val_accuracy: 0.6577 - 6s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 6s - loss: 1.1789 - accuracy: 0.6779 - val_loss: 1.1157 - val_accuracy: 0.6892 - 6s/epoch - 3ms/step
# Epoch 5/10
# 1920/1920 - 6s - loss: 1.0592 - accuracy: 0.7042 - val_loss: 1.0123 - val_accuracy: 0.7102 - 6s/epoch - 3ms/step
# Epoch 6/10
# 1920/1920 - 6s - loss: 0.9664 - accuracy: 0.7261 - val_loss: 0.9363 - val_accuracy: 0.7273 - 6s/epoch - 3ms/step
# Epoch 7/10
# 1920/1920 - 6s - loss: 0.8925 - accuracy: 0.7435 - val_loss: 0.8736 - val_accuracy: 0.7415 - 6s/epoch - 3ms/step
# Epoch 8/10
# 1920/1920 - 6s - loss: 0.8333 - accuracy: 0.7572 - val_loss: 0.8285 - val_accuracy: 0.7514 - 6s/epoch - 3ms/step
# Epoch 9/10
# 1920/1920 - 6s - loss: 0.7847 - accuracy: 0.7687 - val_loss: 0.7832 - val_accuracy: 0.7625 - 6s/epoch - 3ms/step
# Epoch 10/10
# 1920/1920 - 6s - loss: 0.7439 - accuracy: 0.7784 - val_loss: 0.7521 - val_accuracy: 0.7695 - 6s/epoch - 3ms/step
# Processing combination: optimizer=adam
# Epoch 1/10
# 1920/1920 - 7s - loss: 2.5843 - accuracy: 0.3915 - val_loss: 1.8921 - val_accuracy: 0.5442 - 7s/epoch - 4ms/step
# Epoch 2/10
# 1920/1920 - 6s - loss: 1.6435 - accuracy: 0.5899 - val_loss: 1.4484 - val_accuracy: 0.6208 - 6s/epoch - 3ms/step
# Epoch 3/10
# 1920/1920 - 6s - loss: 1.3477 - accuracy: 0.6419 - val_loss: 1.2509 - val_accuracy: 0.6578 - 6s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 6s - loss: 1.1832 - accuracy: 0.6763 - val_loss: 1.1200 - val_accuracy: 0.6865 - 6s/epoch - 3ms/step
# Epoch 5/10
# 1920/1920 - 6s - loss: 1.0654 - accuracy: 0.7024 - val_loss: 1.0227 - val_accuracy: 0.7072 - 6s/epoch - 3ms/step
# Epoch 6/10
# 1920/1920 - 6s - loss: 0.9734 - accuracy: 0.7232 - val_loss: 0.9424 - val_accuracy: 0.7254 - 6s/epoch - 3ms/step
# Epoch 7/10
# 1920/1920 - 5s - loss: 0.8992 - accuracy: 0.7395 - val_loss: 0.8819 - val_accuracy: 0.7382 - 5s/epoch - 3ms/step
# Epoch 8/10
# 1920/1920 - 6s - loss: 0.8390 - accuracy: 0.7534 - val_loss: 0.8294 - val_accuracy: 0.7508 - 6s/epoch - 3ms/step
# Epoch 9/10
# 1920/1920 - 6s - loss: 0.7889 - accuracy: 0.7677 - val_loss: 0.7934 - val_accuracy: 0.7596 - 6s/epoch - 3ms/step
# Epoch 10/10
# 1920/1920 - 6s - loss: 0.7471 - accuracy: 0.7773 - val_loss: 0.7544 - val_accuracy: 0.7682 - 6s/epoch - 3ms/step
# Processing combination: optimizer=adagrad
# Epoch 1/10
# 1920/1920 - 6s - loss: 2.6338 - accuracy: 0.3791 - val_loss: 1.9340 - val_accuracy: 0.5350 - 6s/epoch - 3ms/step
# Epoch 2/10
# 1920/1920 - 6s - loss: 1.6692 - accuracy: 0.5833 - val_loss: 1.4725 - val_accuracy: 0.6157 - 6s/epoch - 3ms/step
# Epoch 3/10
# 1920/1920 - 6s - loss: 1.3606 - accuracy: 0.6390 - val_loss: 1.2647 - val_accuracy: 0.6570 - 6s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 7s - loss: 1.1900 - accuracy: 0.6751 - val_loss: 1.1283 - val_accuracy: 0.6867 - 7s/epoch - 3ms/step
# Epoch 5/10
# 1920/1920 - 7s - loss: 1.0691 - accuracy: 0.7024 - val_loss: 1.0264 - val_accuracy: 0.7074 - 7s/epoch - 3ms/step
# Epoch 6/10
# 1920/1920 - 6s - loss: 0.9763 - accuracy: 0.7245 - val_loss: 0.9471 - val_accuracy: 0.7258 - 6s/epoch - 3ms/step
# Epoch 7/10
# 1920/1920 - 5s - loss: 0.9033 - accuracy: 0.7401 - val_loss: 0.8864 - val_accuracy: 0.7393 - 5s/epoch - 3ms/step
# Epoch 8/10
# 1920/1920 - 6s - loss: 0.8453 - accuracy: 0.7547 - val_loss: 0.8376 - val_accuracy: 0.7507 - 6s/epoch - 3ms/step
# Epoch 9/10
# 1920/1920 - 6s - loss: 0.7970 - accuracy: 0.7661 - val_loss: 0.7979 - val_accuracy: 0.7584 - 6s/epoch - 3ms/step
# Epoch 10/10
# 1920/1920 - 6s - loss: 0.7568 - accuracy: 0.7762 - val_loss: 0.7654 - val_accuracy: 0.7674 - 6s/epoch - 3ms/step
# Best Accuracy of optimizer: 0.7914893627166748
# Best Hyperparameters:
# 	- activation: tanh
# Processing combination: learning_rate_scheduler=exp
# Epoch 1/10
# 1920/1920 - 7s - loss: 2.6131 - accuracy: 0.3877 - val_loss: 1.8853 - val_accuracy: 0.5491 - 7s/epoch - 4ms/step
# Epoch 2/10
# 1920/1920 - 6s - loss: 1.6218 - accuracy: 0.5959 - val_loss: 1.4348 - val_accuracy: 0.6262 - 6s/epoch - 3ms/step
# Epoch 3/10
# 1920/1920 - 6s - loss: 1.3249 - accuracy: 0.6480 - val_loss: 1.2342 - val_accuracy: 0.6622 - 6s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 5s - loss: 1.1615 - accuracy: 0.6816 - val_loss: 1.1039 - val_accuracy: 0.6906 - 5s/epoch - 3ms/step
# Epoch 5/10
# 1920/1920 - 6s - loss: 1.0448 - accuracy: 0.7078 - val_loss: 1.0034 - val_accuracy: 0.7153 - 6s/epoch - 3ms/step
# Epoch 6/10
# 1920/1920 - 6s - loss: 0.9553 - accuracy: 0.7274 - val_loss: 0.9312 - val_accuracy: 0.7307 - 6s/epoch - 3ms/step
# Epoch 7/10
# 1920/1920 - 9s - loss: 0.8853 - accuracy: 0.7439 - val_loss: 0.8688 - val_accuracy: 0.7458 - 9s/epoch - 5ms/step
# Epoch 8/10
# 1920/1920 - 7s - loss: 0.8287 - accuracy: 0.7578 - val_loss: 0.8234 - val_accuracy: 0.7526 - 7s/epoch - 3ms/step
# Epoch 9/10
# 1920/1920 - 6s - loss: 0.7823 - accuracy: 0.7702 - val_loss: 0.7822 - val_accuracy: 0.7667 - 6s/epoch - 3ms/step
# Epoch 10/10
# 1920/1920 - 6s - loss: 0.7430 - accuracy: 0.7796 - val_loss: 0.7515 - val_accuracy: 0.7720 - 6s/epoch - 3ms/step
# Processing combination: learning_rate_scheduler=invdecay
# Epoch 1/10
# 1920/1920 - 7s - loss: 2.6371 - accuracy: 0.3835 - val_loss: 1.8960 - val_accuracy: 0.5503 - 7s/epoch - 4ms/step
# Epoch 2/10
# 1920/1920 - 6s - loss: 1.6307 - accuracy: 0.5918 - val_loss: 1.4316 - val_accuracy: 0.6257 - 6s/epoch - 3ms/step
# Epoch 3/10
# 1920/1920 - 6s - loss: 1.3261 - accuracy: 0.6473 - val_loss: 1.2313 - val_accuracy: 0.6630 - 6s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 6s - loss: 1.1636 - accuracy: 0.6825 - val_loss: 1.1064 - val_accuracy: 0.6907 - 6s/epoch - 3ms/step
# Epoch 5/10
# 1920/1920 - 6s - loss: 1.0506 - accuracy: 0.7081 - val_loss: 1.0102 - val_accuracy: 0.7117 - 6s/epoch - 3ms/step
# Epoch 6/10
# 1920/1920 - 6s - loss: 0.9637 - accuracy: 0.7275 - val_loss: 0.9380 - val_accuracy: 0.7276 - 6s/epoch - 3ms/step
# Epoch 7/10
# 1920/1920 - 6s - loss: 0.8938 - accuracy: 0.7433 - val_loss: 0.8790 - val_accuracy: 0.7414 - 6s/epoch - 3ms/step
# Epoch 8/10
# 1920/1920 - 6s - loss: 0.8363 - accuracy: 0.7572 - val_loss: 0.8294 - val_accuracy: 0.7542 - 6s/epoch - 3ms/step
# Epoch 9/10
# 1920/1920 - 6s - loss: 0.7890 - accuracy: 0.7676 - val_loss: 0.7903 - val_accuracy: 0.7625 - 6s/epoch - 3ms/step
# Epoch 10/10
# 1920/1920 - 6s - loss: 0.7486 - accuracy: 0.7780 - val_loss: 0.7605 - val_accuracy: 0.7672 - 6s/epoch - 3ms/step
# Best Accuracy of learning_rate_scheduler: 0.7914893627166748
# Best Hyperparameters:
# 	- activation: tanh
# Processing combination: regularizer=<keras.src.regularizers.L1 object at 0x0000020105581810>
# Epoch 1/10
# 1920/1920 - 7s - loss: 2.5874 - accuracy: 0.3936 - val_loss: 1.8978 - val_accuracy: 0.5454 - 7s/epoch - 3ms/step
# Epoch 2/10
# 1920/1920 - 5s - loss: 1.6449 - accuracy: 0.5894 - val_loss: 1.4632 - val_accuracy: 0.6192 - 5s/epoch - 2ms/step
# Epoch 3/10
# 1920/1920 - 6s - loss: 1.3511 - accuracy: 0.6425 - val_loss: 1.2599 - val_accuracy: 0.6598 - 6s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 5s - loss: 1.1839 - accuracy: 0.6781 - val_loss: 1.1233 - val_accuracy: 0.6871 - 5s/epoch - 3ms/step
# Epoch 5/10
# 1920/1920 - 5s - loss: 1.0631 - accuracy: 0.7043 - val_loss: 1.0229 - val_accuracy: 0.7098 - 5s/epoch - 3ms/step
# Epoch 6/10
# 1920/1920 - 5s - loss: 0.9681 - accuracy: 0.7255 - val_loss: 0.9396 - val_accuracy: 0.7273 - 5s/epoch - 3ms/step
# Epoch 7/10
# 1920/1920 - 6s - loss: 0.8922 - accuracy: 0.7426 - val_loss: 0.8749 - val_accuracy: 0.7421 - 6s/epoch - 3ms/step
# Epoch 8/10
# 1920/1920 - 6s - loss: 0.8311 - accuracy: 0.7573 - val_loss: 0.8227 - val_accuracy: 0.7536 - 6s/epoch - 3ms/step
# Epoch 9/10
# 1920/1920 - 6s - loss: 0.7807 - accuracy: 0.7707 - val_loss: 0.7838 - val_accuracy: 0.7634 - 6s/epoch - 3ms/step
# Epoch 10/10
# 1920/1920 - 6s - loss: 0.7392 - accuracy: 0.7800 - val_loss: 0.7482 - val_accuracy: 0.7725 - 6s/epoch - 3ms/step
# Processing combination: regularizer=<keras.src.regularizers.L2 object at 0x0000020105583E80>
# Epoch 1/10
# 1920/1920 - 7s - loss: 2.6313 - accuracy: 0.3834 - val_loss: 1.9080 - val_accuracy: 0.5471 - 7s/epoch - 4ms/step
# Epoch 2/10
# 1920/1920 - 6s - loss: 1.6391 - accuracy: 0.5898 - val_loss: 1.4414 - val_accuracy: 0.6235 - 6s/epoch - 3ms/step
# Epoch 3/10
# 1920/1920 - 6s - loss: 1.3331 - accuracy: 0.6453 - val_loss: 1.2401 - val_accuracy: 0.6606 - 6s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 10s - loss: 1.1665 - accuracy: 0.6802 - val_loss: 1.1077 - val_accuracy: 0.6900 - 10s/epoch - 5ms/step
# Epoch 5/10
# 1920/1920 - 11s - loss: 1.0477 - accuracy: 0.7071 - val_loss: 1.0071 - val_accuracy: 0.7103 - 11s/epoch - 6ms/step
# Epoch 6/10
# 1920/1920 - 11s - loss: 0.9560 - accuracy: 0.7274 - val_loss: 0.9306 - val_accuracy: 0.7286 - 11s/epoch - 6ms/step
# Epoch 7/10
# 1920/1920 - 10s - loss: 0.8834 - accuracy: 0.7443 - val_loss: 0.8709 - val_accuracy: 0.7421 - 10s/epoch - 5ms/step
# Epoch 8/10
# 1920/1920 - 6s - loss: 0.8248 - accuracy: 0.7589 - val_loss: 0.8192 - val_accuracy: 0.7549 - 6s/epoch - 3ms/step
# Epoch 9/10
# 1920/1920 - 6s - loss: 0.7761 - accuracy: 0.7703 - val_loss: 0.7796 - val_accuracy: 0.7631 - 6s/epoch - 3ms/step
# Epoch 10/10
# 1920/1920 - 7s - loss: 0.7352 - accuracy: 0.7812 - val_loss: 0.7460 - val_accuracy: 0.7717 - 7s/epoch - 4ms/step
# Processing combination: regularizer=None
# Epoch 1/10
# 1920/1920 - 8s - loss: 2.6071 - accuracy: 0.3894 - val_loss: 1.8853 - val_accuracy: 0.5423 - 8s/epoch - 4ms/step
# Epoch 2/10
# 1920/1920 - 5s - loss: 1.6405 - accuracy: 0.5861 - val_loss: 1.4531 - val_accuracy: 0.6193 - 5s/epoch - 3ms/step
# Epoch 3/10
# 1920/1920 - 6s - loss: 1.3532 - accuracy: 0.6401 - val_loss: 1.2610 - val_accuracy: 0.6570 - 6s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 6s - loss: 1.1931 - accuracy: 0.6757 - val_loss: 1.1340 - val_accuracy: 0.6859 - 6s/epoch - 3ms/step
# Epoch 5/10
# 1920/1920 - 10s - loss: 1.0774 - accuracy: 0.7014 - val_loss: 1.0358 - val_accuracy: 0.7084 - 10s/epoch - 5ms/step
# Epoch 6/10
# 1920/1920 - 11s - loss: 0.9846 - accuracy: 0.7216 - val_loss: 0.9519 - val_accuracy: 0.7279 - 11s/epoch - 6ms/step
# Epoch 7/10
# 1920/1920 - 11s - loss: 0.9087 - accuracy: 0.7399 - val_loss: 0.8919 - val_accuracy: 0.7405 - 11s/epoch - 6ms/step
# Epoch 8/10
# 1920/1920 - 11s - loss: 0.8468 - accuracy: 0.7545 - val_loss: 0.8359 - val_accuracy: 0.7541 - 11s/epoch - 6ms/step
# Epoch 9/10
# 1920/1920 - 11s - loss: 0.7960 - accuracy: 0.7670 - val_loss: 0.7938 - val_accuracy: 0.7620 - 11s/epoch - 6ms/step
# Epoch 10/10
# 1920/1920 - 11s - loss: 0.7541 - accuracy: 0.7774 - val_loss: 0.7587 - val_accuracy: 0.7701 - 11s/epoch - 6ms/step
# Best Accuracy of regularizer: 0.7914893627166748
# Best Hyperparameters:
# 	- activation: tanh
# Processing combination: use_dropout=True
# Epoch 1/10
# 1920/1920 - 13s - loss: 2.5949 - accuracy: 0.3920 - val_loss: 1.9004 - val_accuracy: 0.5465 - 13s/epoch - 7ms/step
# Epoch 2/10
# 1920/1920 - 11s - loss: 1.6409 - accuracy: 0.5903 - val_loss: 1.4525 - val_accuracy: 0.6193 - 11s/epoch - 6ms/step
# Epoch 3/10
# 1920/1920 - 11s - loss: 1.3451 - accuracy: 0.6448 - val_loss: 1.2564 - val_accuracy: 0.6611 - 11s/epoch - 6ms/step
# Epoch 4/10
# 1920/1920 - 11s - loss: 1.1838 - accuracy: 0.6793 - val_loss: 1.1254 - val_accuracy: 0.6900 - 11s/epoch - 6ms/step
# Epoch 5/10
# 1920/1920 - 11s - loss: 1.0666 - accuracy: 0.7053 - val_loss: 1.0252 - val_accuracy: 0.7108 - 11s/epoch - 6ms/step
# Epoch 6/10
# 1920/1920 - 11s - loss: 0.9737 - accuracy: 0.7261 - val_loss: 0.9485 - val_accuracy: 0.7303 - 11s/epoch - 6ms/step
# Epoch 7/10
# 1920/1920 - 12s - loss: 0.8981 - accuracy: 0.7442 - val_loss: 0.8846 - val_accuracy: 0.7453 - 12s/epoch - 6ms/step
# Epoch 8/10
# 1920/1920 - 11s - loss: 0.8369 - accuracy: 0.7578 - val_loss: 0.8327 - val_accuracy: 0.7535 - 11s/epoch - 6ms/step
# Epoch 9/10
# 1920/1920 - 11s - loss: 0.7873 - accuracy: 0.7690 - val_loss: 0.7895 - val_accuracy: 0.7655 - 11s/epoch - 6ms/step
# Epoch 10/10
# 1920/1920 - 11s - loss: 0.7458 - accuracy: 0.7795 - val_loss: 0.7554 - val_accuracy: 0.7717 - 11s/epoch - 6ms/step
# Processing combination: use_dropout=False
# Epoch 1/10
# 1920/1920 - 10s - loss: 2.6284 - accuracy: 0.3874 - val_loss: 1.9177 - val_accuracy: 0.5456 - 10s/epoch - 5ms/step
# Epoch 2/10
# 1920/1920 - 6s - loss: 1.6577 - accuracy: 0.5890 - val_loss: 1.4611 - val_accuracy: 0.6188 - 6s/epoch - 3ms/step
# Epoch 3/10
# 1920/1920 - 6s - loss: 1.3562 - accuracy: 0.6425 - val_loss: 1.2597 - val_accuracy: 0.6599 - 6s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 7s - loss: 1.1936 - accuracy: 0.6761 - val_loss: 1.1295 - val_accuracy: 0.6879 - 7s/epoch - 4ms/step
# Epoch 5/10
# 1920/1920 - 6s - loss: 1.0783 - accuracy: 0.7005 - val_loss: 1.0351 - val_accuracy: 0.7078 - 6s/epoch - 3ms/step
# Epoch 6/10
# 1920/1920 - 6s - loss: 0.9876 - accuracy: 0.7217 - val_loss: 0.9563 - val_accuracy: 0.7234 - 6s/epoch - 3ms/step
# Epoch 7/10
# 1920/1920 - 6s - loss: 0.9128 - accuracy: 0.7369 - val_loss: 0.8942 - val_accuracy: 0.7387 - 6s/epoch - 3ms/step
# Epoch 8/10
# 1920/1920 - 6s - loss: 0.8513 - accuracy: 0.7526 - val_loss: 0.8357 - val_accuracy: 0.7514 - 6s/epoch - 3ms/step
# Epoch 9/10
# 1920/1920 - 5s - loss: 0.7997 - accuracy: 0.7651 - val_loss: 0.7935 - val_accuracy: 0.7622 - 5s/epoch - 3ms/step
# Epoch 10/10
# 1920/1920 - 6s - loss: 0.7565 - accuracy: 0.7755 - val_loss: 0.7583 - val_accuracy: 0.7707 - 6s/epoch - 3ms/step
# Best Accuracy of use_dropout: 0.7914893627166748
# Best Hyperparameters:
# 	- activation: tanh
# Processing combination: use_batch_norm=True
# Epoch 1/10
# 1920/1920 - 7s - loss: 2.5935 - accuracy: 0.3905 - val_loss: 1.8875 - val_accuracy: 0.5443 - 7s/epoch - 4ms/step
# Epoch 2/10
# 1920/1920 - 5s - loss: 1.6392 - accuracy: 0.5873 - val_loss: 1.4415 - val_accuracy: 0.6185 - 5s/epoch - 3ms/step
# Epoch 3/10
# 1920/1920 - 6s - loss: 1.3375 - accuracy: 0.6436 - val_loss: 1.2352 - val_accuracy: 0.6629 - 6s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 6s - loss: 1.1694 - accuracy: 0.6795 - val_loss: 1.1049 - val_accuracy: 0.6896 - 6s/epoch - 3ms/step
# Epoch 5/10
# 1920/1920 - 7s - loss: 1.0515 - accuracy: 0.7061 - val_loss: 1.0089 - val_accuracy: 0.7096 - 7s/epoch - 4ms/step
# Epoch 6/10
# 1920/1920 - 6s - loss: 0.9613 - accuracy: 0.7266 - val_loss: 0.9332 - val_accuracy: 0.7300 - 6s/epoch - 3ms/step
# Epoch 7/10
# 1920/1920 - 7s - loss: 0.8891 - accuracy: 0.7440 - val_loss: 0.8724 - val_accuracy: 0.7420 - 7s/epoch - 3ms/step
# Epoch 8/10
# 1920/1920 - 6s - loss: 0.8308 - accuracy: 0.7576 - val_loss: 0.8221 - val_accuracy: 0.7544 - 6s/epoch - 3ms/step
# Epoch 9/10
# 1920/1920 - 6s - loss: 0.7820 - accuracy: 0.7708 - val_loss: 0.7825 - val_accuracy: 0.7643 - 6s/epoch - 3ms/step
# Epoch 10/10
# 1920/1920 - 6s - loss: 0.7413 - accuracy: 0.7802 - val_loss: 0.7511 - val_accuracy: 0.7721 - 6s/epoch - 3ms/step
# Processing combination: use_batch_norm=False
# Epoch 1/10
# 1920/1920 - 7s - loss: 2.6267 - accuracy: 0.3949 - val_loss: 1.8917 - val_accuracy: 0.5449 - 7s/epoch - 4ms/step
# Epoch 2/10
# 1920/1920 - 6s - loss: 1.6220 - accuracy: 0.5950 - val_loss: 1.4319 - val_accuracy: 0.6238 - 6s/epoch - 3ms/step
# Epoch 3/10
# 1920/1920 - 6s - loss: 1.3278 - accuracy: 0.6487 - val_loss: 1.2350 - val_accuracy: 0.6627 - 6s/epoch - 3ms/step
# Epoch 4/10
# 1920/1920 - 6s - loss: 1.1692 - accuracy: 0.6812 - val_loss: 1.1081 - val_accuracy: 0.6903 - 6s/epoch - 3ms/step
# Epoch 5/10
# 1920/1920 - 7s - loss: 1.0554 - accuracy: 0.7054 - val_loss: 1.0109 - val_accuracy: 0.7138 - 7s/epoch - 3ms/step
# Epoch 6/10
# 1920/1920 - 6s - loss: 0.9658 - accuracy: 0.7264 - val_loss: 0.9383 - val_accuracy: 0.7273 - 6s/epoch - 3ms/step
# Epoch 7/10
# 1920/1920 - 7s - loss: 0.8941 - accuracy: 0.7425 - val_loss: 0.8789 - val_accuracy: 0.7391 - 7s/epoch - 4ms/step
# Epoch 8/10
# 1920/1920 - 6s - loss: 0.8358 - accuracy: 0.7569 - val_loss: 0.8293 - val_accuracy: 0.7523 - 6s/epoch - 3ms/step
# Epoch 9/10
# 1920/1920 - 6s - loss: 0.7881 - accuracy: 0.7669 - val_loss: 0.7876 - val_accuracy: 0.7607 - 6s/epoch - 3ms/step
# Epoch 10/10
# 1920/1920 - 6s - loss: 0.7481 - accuracy: 0.7775 - val_loss: 0.7568 - val_accuracy: 0.7704 - 6s/epoch - 3ms/step
# Best Accuracy of use_batch_norm: 0.7914893627166748
# Best Hyperparameters:
# 	- activation: tanh

# %% [markdown]
# The final loop will get us all the best parameters for our model apart from the predefined baseline parameters.

# %%
# Print the best parameters
print(f"Accuracy of Optimised Model: {best_mlp_accuracy}")
print(f"Best Hyperparameters:")
for key, value in best_mlp_params.items():
    print(f"\t- {key}: {value}")
print(f"Total training time: {time}")
# Out:
# Accuracy of Optimised Model: 0.7914893627166748
# Best Hyperparameters:
# 	- activation: tanh
# Total training time: 1147.6766772270203

# %% [markdown]
# ### Training the model with the best hyperparameter that was explored
# Now we train with these best parameters to get out best MLP model.

# %%
# Training with best params
best_mlp = create_mlp(num_classes=len(np.unique(y_train)), **best_mlp_params)
best_mlp_history = best_mlp.fit(x_train, one_hot_y_train, epochs=10, batch_size=47, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 1920/1920 [==============================] - 9s 4ms/step - loss: 2.5675 - accuracy: 0.4014 - val_loss: 1.8754 - val_accuracy: 0.5476
# Epoch 2/10
# 1920/1920 [==============================] - 7s 4ms/step - loss: 1.6250 - accuracy: 0.5927 - val_loss: 1.4405 - val_accuracy: 0.6227
# Epoch 3/10
# 1920/1920 [==============================] - 7s 4ms/step - loss: 1.3306 - accuracy: 0.6478 - val_loss: 1.2392 - val_accuracy: 0.6629
# Epoch 4/10
# 1920/1920 [==============================] - 7s 4ms/step - loss: 1.1676 - accuracy: 0.6804 - val_loss: 1.1094 - val_accuracy: 0.6905
# Epoch 5/10
# 1920/1920 [==============================] - 5s 3ms/step - loss: 1.0533 - accuracy: 0.7038 - val_loss: 1.0119 - val_accuracy: 0.7121
# Epoch 6/10
# 1920/1920 [==============================] - 7s 4ms/step - loss: 0.9654 - accuracy: 0.7231 - val_loss: 0.9351 - val_accuracy: 0.7300
# Epoch 7/10
# 1920/1920 [==============================] - 7s 4ms/step - loss: 0.8948 - accuracy: 0.7401 - val_loss: 0.8760 - val_accuracy: 0.7444
# Epoch 8/10
# 1920/1920 [==============================] - 7s 4ms/step - loss: 0.8376 - accuracy: 0.7542 - val_loss: 0.8279 - val_accuracy: 0.7538
# Epoch 9/10
# 1920/1920 [==============================] - 8s 4ms/step - loss: 0.7901 - accuracy: 0.7661 - val_loss: 0.7895 - val_accuracy: 0.7609
# Epoch 10/10
# 1920/1920 [==============================] - 8s 4ms/step - loss: 0.7504 - accuracy: 0.7760 - val_loss: 0.7555 - val_accuracy: 0.7711

# %% [markdown]
# ## Save the MLP model

# %%
# Saving the MLP model
best_mlp.save("mlp_model.h5", overwrite=True)

# %% [markdown]
# ## Plotting the training graph
# Lets plot the learing graph to check for underfitting or overfitting

# %%
def plot_loss_and_accuracy(model_history, model_name):
    """
    Plots the training and validation loss, as well as training and validation accuracy, from a given model's training history.

    Parameters:
        model_history (History): History object returned by the `fit` method of a Keras model, containing training metrics.
        model_name (str): Name of the model to be displayed as the title of the plot.

    Returns:
        None
    """
    plt.figure(figsize=(12, 4))
    plt.suptitle(model_name)

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(model_history.history['loss'], '-o', label='Training Loss')
    plt.plot(model_history.history['val_loss'], '-o', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(model_history.history['accuracy'], '-o', label='Training Accuracy')
    plt.plot(model_history.history['val_accuracy'], '-o', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()
    
plot_loss_and_accuracy(best_mlp_history, 'MLP')

# %% [markdown]
# # CNN
# ### We now follow the exact steps as we did for MLP, to find the best hyperparameters by fine tuning them for our CNN model

# %%
# Build and Train CNN Base Model
cnn_base = create_cnn(num_classes=len(np.unique(y_train)))
cnn_base_history = cnn_base.fit(x_train, one_hot_y_train, epochs=10, batch_size=47, validation_split=0.2, verbose=1)
# Out:
# WARNING:tensorflow:From c:\Users\roy_q\anaconda3\envs\pyTF\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Epoch 1/10
# 1920/1920 [==============================] - 79s 41ms/step - loss: 1.0478 - accuracy: 0.6834 - val_loss: 0.9789 - val_accuracy: 0.7027
# Epoch 2/10
# 1920/1920 [==============================] - 70s 36ms/step - loss: 0.9794 - accuracy: 0.7080 - val_loss: 0.9010 - val_accuracy: 0.7233
# Epoch 3/10
# 1920/1920 [==============================] - 64s 34ms/step - loss: 0.9695 - accuracy: 0.7101 - val_loss: 0.9222 - val_accuracy: 0.7241
# Epoch 4/10
# 1920/1920 [==============================] - 54s 28ms/step - loss: 0.9545 - accuracy: 0.7140 - val_loss: 0.9919 - val_accuracy: 0.7047
# Epoch 5/10
# 1920/1920 [==============================] - 56s 29ms/step - loss: 0.9324 - accuracy: 0.7177 - val_loss: 1.0691 - val_accuracy: 0.6913
# Epoch 6/10
# 1920/1920 [==============================] - 59s 31ms/step - loss: 0.9430 - accuracy: 0.7151 - val_loss: 0.9994 - val_accuracy: 0.6997
# Epoch 7/10
# 1920/1920 [==============================] - 57s 30ms/step - loss: 0.9248 - accuracy: 0.7217 - val_loss: 0.8978 - val_accuracy: 0.7328
# Epoch 8/10
# 1920/1920 [==============================] - 56s 29ms/step - loss: 0.8922 - accuracy: 0.7299 - val_loss: 0.9082 - val_accuracy: 0.7225
# Epoch 9/10
# 1920/1920 [==============================] - 80s 41ms/step - loss: 0.8912 - accuracy: 0.7312 - val_loss: 0.9470 - val_accuracy: 0.7120
# Epoch 10/10
# 1920/1920 [==============================] - 67s 35ms/step - loss: 0.8981 - accuracy: 0.7294 - val_loss: 0.9323 - val_accuracy: 0.7175

# %%
# Get validation accuracy and loss from history object
final_cnn_val_accuracy = cnn_base_history.history['val_accuracy'][-1]
final_cnn_val_loss = cnn_base_history.history['val_loss'][-1]

print("Accuracy of Base CNN Model:", final_cnn_val_accuracy)
print("Loss of Base CNN Model:", final_cnn_val_loss)
# Out:
# Accuracy of Base CNN Model: 0.7175
# Loss of Base CNN Model: 0.9323

# %% [markdown]
# ### Hyperparameter Tuning
# Now we fine tune our CNN base model by exploring different techniques

# %%
# Tuning the hyperparameter
best_cnn_params, best_cnn_accuracy, time = optimize_hyperparameters(hyperparameter_dict, x_train, one_hot_y_train, model_name='cnn')
# Out:
# Processing combination: activation=relu
# Epoch 1/10
# 1920/1920 - 25s - loss: 2.6530 - accuracy: 0.6384 - val_loss: 1.4726 - val_accuracy: 0.7655 - 25s/epoch - 13ms/step
# Epoch 2/10
# 1920/1920 - 30s - loss: 1.2305 - accuracy: 0.7867 - val_loss: 1.0791 - val_accuracy: 0.7975 - 30s/epoch - 16ms/step
# Epoch 3/10
# 1920/1920 - 37s - loss: 1.0112 - accuracy: 0.8093 - val_loss: 0.9657 - val_accuracy: 0.8128 - 37s/epoch - 19ms/step
# Epoch 4/10
# 1920/1920 - 30s - loss: 0.9348 - accuracy: 0.8204 - val_loss: 0.9290 - val_accuracy: 0.8144 - 30s/epoch - 16ms/step
# Epoch 5/10
# 1920/1920 - 41s - loss: 0.8947 - accuracy: 0.8276 - val_loss: 0.8890 - val_accuracy: 0.8262 - 41s/epoch - 21ms/step
# Epoch 6/10
# 1920/1920 - 40s - loss: 0.8700 - accuracy: 0.8325 - val_loss: 0.8766 - val_accuracy: 0.8274 - 40s/epoch - 21ms/step
# Epoch 7/10
# 1920/1920 - 38s - loss: 0.8528 - accuracy: 0.8355 - val_loss: 0.8701 - val_accuracy: 0.8258 - 38s/epoch - 20ms/step
# Epoch 8/10
# 1920/1920 - 39s - loss: 0.8394 - accuracy: 0.8386 - val_loss: 0.8464 - val_accuracy: 0.8317 - 39s/epoch - 20ms/step
# Epoch 9/10
# 1920/1920 - 43s - loss: 0.8290 - accuracy: 0.8397 - val_loss: 0.8531 - val_accuracy: 0.8266 - 43s/epoch - 22ms/step
# Epoch 10/10
# 1920/1920 - 43s - loss: 0.8202 - accuracy: 0.8431 - val_loss: 0.8358 - val_accuracy: 0.8355 - 43s/epoch - 22ms/step
# Processing combination: activation=elu
# Epoch 1/10
# 1920/1920 - 40s - loss: 2.8044 - accuracy: 0.5923 - val_loss: 1.5530 - val_accuracy: 0.7371 - 40s/epoch - 21ms/step
# Epoch 2/10
# 1920/1920 - 37s - loss: 1.2653 - accuracy: 0.7778 - val_loss: 1.1219 - val_accuracy: 0.7905 - 37s/epoch - 19ms/step
# Epoch 3/10
# 1920/1920 - 37s - loss: 1.0488 - accuracy: 0.8024 - val_loss: 1.0170 - val_accuracy: 0.8025 - 37s/epoch - 19ms/step
# Epoch 4/10
# 1920/1920 - 37s - loss: 0.9695 - accuracy: 0.8157 - val_loss: 0.9622 - val_accuracy: 0.8109 - 37s/epoch - 19ms/step
# Epoch 5/10
# 1920/1920 - 36s - loss: 0.9289 - accuracy: 0.8218 - val_loss: 0.9288 - val_accuracy: 0.8154 - 36s/epoch - 19ms/step
# Epoch 6/10
# 1920/1920 - 36s - loss: 0.9022 - accuracy: 0.8262 - val_loss: 0.9033 - val_accuracy: 0.8237 - 36s/epoch - 19ms/step
# Epoch 7/10
# 1920/1920 - 36s - loss: 0.8829 - accuracy: 0.8318 - val_loss: 0.8907 - val_accuracy: 0.8247 - 36s/epoch - 19ms/step
# Epoch 8/10
# 1920/1920 - 44s - loss: 0.8684 - accuracy: 0.8345 - val_loss: 0.8779 - val_accuracy: 0.8265 - 44s/epoch - 23ms/step
# Epoch 9/10
# 1920/1920 - 38s - loss: 0.8563 - accuracy: 0.8366 - val_loss: 0.8784 - val_accuracy: 0.8240 - 38s/epoch - 20ms/step
# Epoch 10/10
# 1920/1920 - 39s - loss: 0.8474 - accuracy: 0.8397 - val_loss: 0.8678 - val_accuracy: 0.8289 - 39s/epoch - 20ms/step
# Processing combination: activation=tanh
# Epoch 1/10
# 1920/1920 - 41s - loss: 2.7161 - accuracy: 0.6161 - val_loss: 1.5017 - val_accuracy: 0.7547 - 41s/epoch - 21ms/step
# Epoch 2/10
# 1920/1920 - 37s - loss: 1.2552 - accuracy: 0.7802 - val_loss: 1.1103 - val_accuracy: 0.7941 - 37s/epoch - 19ms/step
# Epoch 3/10
# 1920/1920 - 44s - loss: 1.0455 - accuracy: 0.8036 - val_loss: 1.0105 - val_accuracy: 0.8032 - 44s/epoch - 23ms/step
# Epoch 4/10
# 1920/1920 - 39s - loss: 0.9721 - accuracy: 0.8153 - val_loss: 0.9700 - val_accuracy: 0.8069 - 39s/epoch - 20ms/step
# Epoch 5/10
# 1920/1920 - 41s - loss: 0.9318 - accuracy: 0.8226 - val_loss: 0.9334 - val_accuracy: 0.8187 - 41s/epoch - 21ms/step
# Epoch 6/10
# 1920/1920 - 38s - loss: 0.9050 - accuracy: 0.8270 - val_loss: 0.9060 - val_accuracy: 0.8227 - 38s/epoch - 20ms/step
# Epoch 7/10
# 1920/1920 - 38s - loss: 0.8867 - accuracy: 0.8312 - val_loss: 0.8999 - val_accuracy: 0.8224 - 38s/epoch - 20ms/step
# Epoch 8/10
# 1920/1920 - 34s - loss: 0.8719 - accuracy: 0.8348 - val_loss: 0.8839 - val_accuracy: 0.8294 - 34s/epoch - 18ms/step
# Epoch 9/10
# 1920/1920 - 39s - loss: 0.8605 - accuracy: 0.8370 - val_loss: 0.8808 - val_accuracy: 0.8234 - 39s/epoch - 20ms/step
# Epoch 10/10
# 1920/1920 - 38s - loss: 0.8505 - accuracy: 0.8379 - val_loss: 0.8664 - val_accuracy: 0.8295 - 38s/epoch - 20ms/step
# Best Accuracy of activation: 0.8355053067207336
# Best Hyperparameters:
# 	- activation: relu
# Processing combination: optimizer=sgd
# Epoch 1/10
# 1920/1920 - 41s - loss: 2.7475 - accuracy: 0.6135 - val_loss: 1.5051 - val_accuracy: 0.7552 - 41s/epoch - 21ms/step
# Epoch 2/10
# 1920/1920 - 39s - loss: 1.2725 - accuracy: 0.7786 - val_loss: 1.1512 - val_accuracy: 0.7798 - 39s/epoch - 20ms/step
# Epoch 3/10
# 1920/1920 - 39s - loss: 1.0566 - accuracy: 0.8040 - val_loss: 1.0134 - val_accuracy: 0.8074 - 39s/epoch - 20ms/step
# Epoch 4/10
# 1920/1920 - 40s - loss: 0.9771 - accuracy: 0.8159 - val_loss: 0.9809 - val_accuracy: 0.8042 - 40s/epoch - 21ms/step
# Epoch 5/10
# 1920/1920 - 38s - loss: 0.9348 - accuracy: 0.8233 - val_loss: 0.9342 - val_accuracy: 0.8132 - 38s/epoch - 20ms/step
# Epoch 6/10
# 1920/1920 - 38s - loss: 0.9075 - accuracy: 0.8277 - val_loss: 0.9139 - val_accuracy: 0.8208 - 38s/epoch - 20ms/step
# Epoch 7/10
# 1920/1920 - 36s - loss: 0.8874 - accuracy: 0.8325 - val_loss: 0.9031 - val_accuracy: 0.8169 - 36s/epoch - 19ms/step
# Epoch 8/10
# 1920/1920 - 38s - loss: 0.8715 - accuracy: 0.8353 - val_loss: 0.8927 - val_accuracy: 0.8242 - 38s/epoch - 20ms/step
# Epoch 9/10
# 1920/1920 - 39s - loss: 0.8600 - accuracy: 0.8383 - val_loss: 0.8805 - val_accuracy: 0.8253 - 39s/epoch - 20ms/step
# Epoch 10/10
# 1920/1920 - 38s - loss: 0.8505 - accuracy: 0.8402 - val_loss: 0.8677 - val_accuracy: 0.8284 - 38s/epoch - 20ms/step
# Processing combination: optimizer=adam
# Epoch 1/10
# 1920/1920 - 42s - loss: 2.7339 - accuracy: 0.6156 - val_loss: 1.5007 - val_accuracy: 0.7577 - 42s/epoch - 22ms/step
# Epoch 2/10
# 1920/1920 - 39s - loss: 1.2665 - accuracy: 0.7797 - val_loss: 1.1177 - val_accuracy: 0.7920 - 39s/epoch - 20ms/step
# Epoch 3/10
# 1920/1920 - 39s - loss: 1.0551 - accuracy: 0.8045 - val_loss: 1.0142 - val_accuracy: 0.8081 - 39s/epoch - 20ms/step
# Epoch 4/10
# 1920/1920 - 39s - loss: 0.9790 - accuracy: 0.8148 - val_loss: 0.9761 - val_accuracy: 0.8076 - 39s/epoch - 20ms/step
# Epoch 5/10
# 1920/1920 - 39s - loss: 0.9383 - accuracy: 0.8210 - val_loss: 0.9315 - val_accuracy: 0.8205 - 39s/epoch - 20ms/step
# Epoch 6/10
# 1920/1920 - 35s - loss: 0.9116 - accuracy: 0.8272 - val_loss: 0.9165 - val_accuracy: 0.8213 - 35s/epoch - 18ms/step
# Epoch 7/10
# 1920/1920 - 28s - loss: 0.8925 - accuracy: 0.8313 - val_loss: 0.8972 - val_accuracy: 0.8258 - 28s/epoch - 15ms/step
# Epoch 8/10
# 1920/1920 - 28s - loss: 0.8772 - accuracy: 0.8333 - val_loss: 0.8912 - val_accuracy: 0.8250 - 28s/epoch - 14ms/step
# Epoch 9/10
# 1920/1920 - 28s - loss: 0.8652 - accuracy: 0.8362 - val_loss: 0.8780 - val_accuracy: 0.8304 - 28s/epoch - 14ms/step
# Epoch 10/10
# 1920/1920 - 24s - loss: 0.8555 - accuracy: 0.8372 - val_loss: 0.8731 - val_accuracy: 0.8297 - 24s/epoch - 12ms/step
# Processing combination: optimizer=adagrad
# Epoch 1/10
# 1920/1920 - 28s - loss: 2.8071 - accuracy: 0.5928 - val_loss: 1.4978 - val_accuracy: 0.7563 - 28s/epoch - 15ms/step
# Epoch 2/10
# 1920/1920 - 27s - loss: 1.2707 - accuracy: 0.7767 - val_loss: 1.1179 - val_accuracy: 0.7948 - 27s/epoch - 14ms/step
# Epoch 3/10
# 1920/1920 - 30s - loss: 1.0560 - accuracy: 0.8028 - val_loss: 1.0200 - val_accuracy: 0.8059 - 30s/epoch - 16ms/step
# Epoch 4/10
# 1920/1920 - 37s - loss: 0.9806 - accuracy: 0.8132 - val_loss: 0.9798 - val_accuracy: 0.8078 - 37s/epoch - 19ms/step
# Epoch 5/10
# 1920/1920 - 36s - loss: 0.9394 - accuracy: 0.8199 - val_loss: 0.9439 - val_accuracy: 0.8141 - 36s/epoch - 19ms/step
# Epoch 6/10
# 1920/1920 - 25s - loss: 0.9120 - accuracy: 0.8252 - val_loss: 0.9106 - val_accuracy: 0.8219 - 25s/epoch - 13ms/step
# Epoch 7/10
# 1920/1920 - 28s - loss: 0.8925 - accuracy: 0.8286 - val_loss: 0.9028 - val_accuracy: 0.8246 - 28s/epoch - 15ms/step
# Epoch 8/10
# 1920/1920 - 27s - loss: 0.8775 - accuracy: 0.8327 - val_loss: 0.8921 - val_accuracy: 0.8233 - 27s/epoch - 14ms/step
# Epoch 9/10
# 1920/1920 - 28s - loss: 0.8652 - accuracy: 0.8354 - val_loss: 0.8784 - val_accuracy: 0.8264 - 28s/epoch - 15ms/step
# Epoch 10/10
# 1920/1920 - 28s - loss: 0.8563 - accuracy: 0.8371 - val_loss: 0.8720 - val_accuracy: 0.8296 - 28s/epoch - 15ms/step
# Best Accuracy of optimizer: 0.8355053067207336
# Best Hyperparameters:
# 	- activation: relu
# Processing combination: learning_rate_scheduler=exp
# Epoch 1/10
# 1920/1920 - 25s - loss: 2.8166 - accuracy: 0.5904 - val_loss: 1.5193 - val_accuracy: 0.7465 - 25s/epoch - 13ms/step
# Epoch 2/10
# 1920/1920 - 25s - loss: 1.2690 - accuracy: 0.7763 - val_loss: 1.1263 - val_accuracy: 0.7869 - 25s/epoch - 13ms/step
# Epoch 3/10
# 1920/1920 - 34s - loss: 1.0540 - accuracy: 0.8014 - val_loss: 1.0179 - val_accuracy: 0.8014 - 34s/epoch - 18ms/step
# Epoch 4/10
# 1920/1920 - 37s - loss: 0.9764 - accuracy: 0.8124 - val_loss: 0.9684 - val_accuracy: 0.8082 - 37s/epoch - 19ms/step
# Epoch 5/10
# 1920/1920 - 34s - loss: 0.9332 - accuracy: 0.8199 - val_loss: 0.9334 - val_accuracy: 0.8150 - 34s/epoch - 18ms/step
# Epoch 6/10
# 1920/1920 - 25s - loss: 0.9062 - accuracy: 0.8258 - val_loss: 0.9102 - val_accuracy: 0.8199 - 25s/epoch - 13ms/step
# Epoch 7/10
# 1920/1920 - 28s - loss: 0.8860 - accuracy: 0.8293 - val_loss: 0.9041 - val_accuracy: 0.8176 - 28s/epoch - 15ms/step
# Epoch 8/10
# 1920/1920 - 28s - loss: 0.8714 - accuracy: 0.8332 - val_loss: 0.8880 - val_accuracy: 0.8228 - 28s/epoch - 15ms/step
# Epoch 9/10
# 1920/1920 - 28s - loss: 0.8588 - accuracy: 0.8357 - val_loss: 0.8764 - val_accuracy: 0.8258 - 28s/epoch - 15ms/step
# Epoch 10/10
# 1920/1920 - 28s - loss: 0.8498 - accuracy: 0.8367 - val_loss: 0.8680 - val_accuracy: 0.8292 - 28s/epoch - 14ms/step
# Processing combination: learning_rate_scheduler=invdecay
# Epoch 1/10
# 1920/1920 - 25s - loss: 2.7451 - accuracy: 0.6062 - val_loss: 1.5137 - val_accuracy: 0.7520 - 25s/epoch - 13ms/step
# Epoch 2/10
# 1920/1920 - 24s - loss: 1.2679 - accuracy: 0.7792 - val_loss: 1.1382 - val_accuracy: 0.7858 - 24s/epoch - 13ms/step
# Epoch 3/10
# 1920/1920 - 36s - loss: 1.0564 - accuracy: 0.8021 - val_loss: 1.0181 - val_accuracy: 0.8037 - 36s/epoch - 19ms/step
# Epoch 4/10
# 1920/1920 - 37s - loss: 0.9787 - accuracy: 0.8149 - val_loss: 0.9598 - val_accuracy: 0.8117 - 37s/epoch - 19ms/step
# Epoch 5/10
# 1920/1920 - 29s - loss: 0.9361 - accuracy: 0.8205 - val_loss: 0.9373 - val_accuracy: 0.8177 - 29s/epoch - 15ms/step
# Epoch 6/10
# 1920/1920 - 27s - loss: 0.9079 - accuracy: 0.8262 - val_loss: 0.9059 - val_accuracy: 0.8244 - 27s/epoch - 14ms/step
# Epoch 7/10
# 1920/1920 - 28s - loss: 0.8885 - accuracy: 0.8294 - val_loss: 0.8996 - val_accuracy: 0.8250 - 28s/epoch - 14ms/step
# Epoch 8/10
# 1920/1920 - 27s - loss: 0.8732 - accuracy: 0.8337 - val_loss: 0.8896 - val_accuracy: 0.8230 - 27s/epoch - 14ms/step
# Epoch 9/10
# 1920/1920 - 25s - loss: 0.8609 - accuracy: 0.8367 - val_loss: 0.8747 - val_accuracy: 0.8267 - 25s/epoch - 13ms/step
# Epoch 10/10
# 1920/1920 - 27s - loss: 0.8511 - accuracy: 0.8387 - val_loss: 0.8723 - val_accuracy: 0.8273 - 27s/epoch - 14ms/step
# Best Accuracy of learning_rate_scheduler: 0.8355053067207336
# Best Hyperparameters:
# 	- activation: relu
# Processing combination: regularizer=l1
# Epoch 1/10
# 1920/1920 - 28s - loss: 2.7817 - accuracy: 0.5989 - val_loss: 1.5388 - val_accuracy: 0.7431 - 28s/epoch - 14ms/step
# Epoch 2/10
# 1920/1920 - 25s - loss: 1.2810 - accuracy: 0.7742 - val_loss: 1.1255 - val_accuracy: 0.7906 - 25s/epoch - 13ms/step
# Epoch 3/10
# 1920/1920 - 37s - loss: 1.0612 - accuracy: 0.8000 - val_loss: 1.0211 - val_accuracy: 0.8062 - 37s/epoch - 19ms/step
# Epoch 4/10
# 1920/1920 - 37s - loss: 0.9802 - accuracy: 0.8118 - val_loss: 0.9687 - val_accuracy: 0.8093 - 37s/epoch - 19ms/step
# Epoch 5/10
# 1920/1920 - 37s - loss: 0.9374 - accuracy: 0.8191 - val_loss: 0.9451 - val_accuracy: 0.8094 - 37s/epoch - 19ms/step
# Epoch 6/10
# 1920/1920 - 37s - loss: 0.9082 - accuracy: 0.8259 - val_loss: 0.9179 - val_accuracy: 0.8193 - 37s/epoch - 19ms/step
# Epoch 7/10
# 1920/1920 - 26s - loss: 0.8879 - accuracy: 0.8298 - val_loss: 0.8950 - val_accuracy: 0.8249 - 26s/epoch - 14ms/step
# Epoch 8/10
# 1920/1920 - 26s - loss: 0.8728 - accuracy: 0.8318 - val_loss: 0.8829 - val_accuracy: 0.8262 - 26s/epoch - 14ms/step
# Epoch 9/10
# 1920/1920 - 27s - loss: 0.8606 - accuracy: 0.8344 - val_loss: 0.8744 - val_accuracy: 0.8259 - 27s/epoch - 14ms/step
# Epoch 10/10
# 1920/1920 - 27s - loss: 0.8503 - accuracy: 0.8372 - val_loss: 0.8636 - val_accuracy: 0.8286 - 27s/epoch - 14ms/step
# Processing combination: regularizer=l2
# Epoch 1/10
# 1920/1920 - 27s - loss: 2.8501 - accuracy: 0.5760 - val_loss: 1.5140 - val_accuracy: 0.7482 - 27s/epoch - 14ms/step
# Epoch 2/10
# 1920/1920 - 28s - loss: 1.2745 - accuracy: 0.7725 - val_loss: 1.1240 - val_accuracy: 0.7920 - 28s/epoch - 14ms/step
# Epoch 3/10
# 1920/1920 - 26s - loss: 1.0620 - accuracy: 0.7999 - val_loss: 1.0242 - val_accuracy: 0.8012 - 26s/epoch - 14ms/step
# Epoch 4/10
# 1920/1920 - 27s - loss: 0.9869 - accuracy: 0.8124 - val_loss: 0.9749 - val_accuracy: 0.8075 - 27s/epoch - 14ms/step
# Epoch 5/10
# 1920/1920 - 37s - loss: 0.9461 - accuracy: 0.8190 - val_loss: 0.9432 - val_accuracy: 0.8161 - 37s/epoch - 19ms/step
# Epoch 6/10
# 1920/1920 - 37s - loss: 0.9187 - accuracy: 0.8244 - val_loss: 0.9242 - val_accuracy: 0.8187 - 37s/epoch - 19ms/step
# Epoch 7/10
# 1920/1920 - 37s - loss: 0.8998 - accuracy: 0.8279 - val_loss: 0.9114 - val_accuracy: 0.8198 - 37s/epoch - 19ms/step
# Epoch 8/10
# 1920/1920 - 37s - loss: 0.8844 - accuracy: 0.8311 - val_loss: 0.8993 - val_accuracy: 0.8216 - 37s/epoch - 19ms/step
# Epoch 9/10
# 1920/1920 - 37s - loss: 0.8726 - accuracy: 0.8324 - val_loss: 0.8889 - val_accuracy: 0.8252 - 37s/epoch - 19ms/step
# Epoch 10/10
# 1920/1920 - 37s - loss: 0.8624 - accuracy: 0.8357 - val_loss: 0.8773 - val_accuracy: 0.8273 - 37s/epoch - 19ms/step
# Best Accuracy of regularizer: 0.8355053067207336
# Best Hyperparameters:
# 	- activation: relu
# Processing combination: use_dropout=True
# Epoch 1/10
# 1920/1920 - 39s - loss: 2.7824 - accuracy: 0.6005 - val_loss: 1.5230 - val_accuracy: 0.7492 - 39s/epoch - 20ms/step
# Epoch 2/10
# 1920/1920 - 37s - loss: 1.2725 - accuracy: 0.7772 - val_loss: 1.1254 - val_accuracy: 0.7877 - 37s/epoch - 19ms/step
# Epoch 3/10
# 1920/1920 - 37s - loss: 1.0557 - accuracy: 0.8032 - val_loss: 1.0126 - val_accuracy: 0.8052 - 37s/epoch - 19ms/step
# Epoch 4/10
# 1920/1920 - 37s - loss: 0.9771 - accuracy: 0.8143 - val_loss: 0.9596 - val_accuracy: 0.8133 - 37s/epoch - 19ms/step
# Epoch 5/10
# 1920/1920 - 37s - loss: 0.9343 - accuracy: 0.8218 - val_loss: 0.9270 - val_accuracy: 0.8199 - 37s/epoch - 19ms/step
# Epoch 6/10
# 1920/1920 - 37s - loss: 0.9060 - accuracy: 0.8266 - val_loss: 0.9123 - val_accuracy: 0.8181 - 37s/epoch - 19ms/step
# Epoch 7/10
# 1920/1920 - 37s - loss: 0.8863 - accuracy: 0.8310 - val_loss: 0.8917 - val_accuracy: 0.8250 - 37s/epoch - 19ms/step
# Epoch 8/10
# 1920/1920 - 29s - loss: 0.8714 - accuracy: 0.8340 - val_loss: 0.8976 - val_accuracy: 0.8206 - 29s/epoch - 15ms/step
# Epoch 9/10
# 1920/1920 - 26s - loss: 0.8589 - accuracy: 0.8371 - val_loss: 0.8708 - val_accuracy: 0.8286 - 26s/epoch - 13ms/step
# Epoch 10/10
# 1920/1920 - 24s - loss: 0.8491 - accuracy: 0.8376 - val_loss: 0.8743 - val_accuracy: 0.8248 - 24s/epoch - 12ms/step
# Processing combination: use_dropout=False
# Epoch 1/10
# 1920/1920 - 27s - loss: 2.7460 - accuracy: 0.6073 - val_loss: 1.5084 - val_accuracy: 0.7498 - 27s/epoch - 14ms/step
# Epoch 2/10
# 1920/1920 - 27s - loss: 1.2563 - accuracy: 0.7798 - val_loss: 1.1238 - val_accuracy: 0.7841 - 27s/epoch - 14ms/step
# Epoch 3/10
# 1920/1920 - 25s - loss: 1.0480 - accuracy: 0.8032 - val_loss: 1.0130 - val_accuracy: 0.8001 - 25s/epoch - 13ms/step
# Epoch 4/10
# 1920/1920 - 27s - loss: 0.9712 - accuracy: 0.8149 - val_loss: 0.9663 - val_accuracy: 0.8074 - 27s/epoch - 14ms/step
# Epoch 5/10
# 1920/1920 - 22s - loss: 0.9296 - accuracy: 0.8209 - val_loss: 0.9209 - val_accuracy: 0.8230 - 22s/epoch - 12ms/step
# Epoch 6/10
# 1920/1920 - 27s - loss: 0.9022 - accuracy: 0.8262 - val_loss: 0.9146 - val_accuracy: 0.8171 - 27s/epoch - 14ms/step
# Epoch 7/10
# 1920/1920 - 26s - loss: 0.8825 - accuracy: 0.8302 - val_loss: 0.8943 - val_accuracy: 0.8254 - 26s/epoch - 14ms/step
# Epoch 8/10
# 1920/1920 - 24s - loss: 0.8678 - accuracy: 0.8334 - val_loss: 0.8879 - val_accuracy: 0.8227 - 24s/epoch - 12ms/step
# Epoch 9/10
# 1920/1920 - 35s - loss: 0.8553 - accuracy: 0.8361 - val_loss: 0.8795 - val_accuracy: 0.8235 - 35s/epoch - 18ms/step
# Epoch 10/10
# 1920/1920 - 38s - loss: 0.8462 - accuracy: 0.8369 - val_loss: 0.8686 - val_accuracy: 0.8261 - 38s/epoch - 20ms/step
# Best Accuracy of use_dropout: 0.8355053067207336
# Best Hyperparameters:
# 	- activation: relu
# Processing combination: use_batch_norm=True
# Epoch 1/10
# 1920/1920 - 40s - loss: 2.7856 - accuracy: 0.5994 - val_loss: 1.4812 - val_accuracy: 0.7644 - 40s/epoch - 21ms/step
# Epoch 2/10
# 1920/1920 - 37s - loss: 1.2513 - accuracy: 0.7823 - val_loss: 1.1126 - val_accuracy: 0.7911 - 37s/epoch - 19ms/step
# Epoch 3/10
# 1920/1920 - 35s - loss: 1.0391 - accuracy: 0.8055 - val_loss: 0.9991 - val_accuracy: 0.8042 - 35s/epoch - 18ms/step
# Epoch 4/10
# 1920/1920 - 24s - loss: 0.9637 - accuracy: 0.8170 - val_loss: 0.9670 - val_accuracy: 0.8078 - 24s/epoch - 12ms/step
# Epoch 5/10
# 1920/1920 - 26s - loss: 0.9221 - accuracy: 0.8219 - val_loss: 0.9282 - val_accuracy: 0.8141 - 26s/epoch - 14ms/step
# Epoch 6/10
# 1920/1920 - 27s - loss: 0.8959 - accuracy: 0.8265 - val_loss: 0.8983 - val_accuracy: 0.8232 - 27s/epoch - 14ms/step
# Epoch 7/10
# 1920/1920 - 27s - loss: 0.8762 - accuracy: 0.8312 - val_loss: 0.8897 - val_accuracy: 0.8234 - 27s/epoch - 14ms/step
# Epoch 8/10
# 1920/1920 - 38s - loss: 0.8609 - accuracy: 0.8347 - val_loss: 0.8725 - val_accuracy: 0.8288 - 38s/epoch - 20ms/step
# Epoch 9/10
# 1920/1920 - 46s - loss: 0.8492 - accuracy: 0.8368 - val_loss: 0.8723 - val_accuracy: 0.8259 - 46s/epoch - 24ms/step
# Epoch 10/10
# 1920/1920 - 49s - loss: 0.8394 - accuracy: 0.8392 - val_loss: 0.8561 - val_accuracy: 0.8320 - 49s/epoch - 25ms/step
# Processing combination: use_batch_norm=False
# Epoch 1/10
# 1920/1920 - 41s - loss: 2.7417 - accuracy: 0.6146 - val_loss: 1.5254 - val_accuracy: 0.7511 - 41s/epoch - 22ms/step
# Epoch 2/10
# 1920/1920 - 42s - loss: 1.2709 - accuracy: 0.7828 - val_loss: 1.1204 - val_accuracy: 0.7930 - 42s/epoch - 22ms/step
# Epoch 3/10
# 1920/1920 - 39s - loss: 1.0554 - accuracy: 0.8033 - val_loss: 1.0133 - val_accuracy: 0.8076 - 39s/epoch - 20ms/step
# Epoch 4/10
# 1920/1920 - 36s - loss: 0.9771 - accuracy: 0.8146 - val_loss: 0.9619 - val_accuracy: 0.8141 - 36s/epoch - 19ms/step
# Epoch 5/10
# 1920/1920 - 36s - loss: 0.9340 - accuracy: 0.8203 - val_loss: 0.9382 - val_accuracy: 0.8149 - 36s/epoch - 19ms/step
# Epoch 6/10
# 1920/1920 - 36s - loss: 0.9053 - accuracy: 0.8266 - val_loss: 0.9091 - val_accuracy: 0.8176 - 36s/epoch - 19ms/step
# Epoch 7/10
# 1920/1920 - 44s - loss: 0.8855 - accuracy: 0.8305 - val_loss: 0.8954 - val_accuracy: 0.8221 - 44s/epoch - 23ms/step
# Epoch 8/10
# 1920/1920 - 40s - loss: 0.8702 - accuracy: 0.8326 - val_loss: 0.8768 - val_accuracy: 0.8285 - 40s/epoch - 21ms/step
# Epoch 9/10
# 1920/1920 - 39s - loss: 0.8576 - accuracy: 0.8355 - val_loss: 0.8696 - val_accuracy: 0.8296 - 39s/epoch - 20ms/step
# Epoch 10/10
# 1920/1920 - 41s - loss: 0.8476 - accuracy: 0.8377 - val_loss: 0.8698 - val_accuracy: 0.8269 - 41s/epoch - 21ms/step
# Best Accuracy of use_batch_norm: 0.8355053067207336
# Best Hyperparameters:
# 	- activation: relu
# Total training time: 4742.093411207199

# %%
# Print the best params
print(f"Accuracy of Optimised Model: {best_cnn_accuracy}")
print(f"Best Hyperparameters:")
for key, value in best_cnn_params.items():
    print(f"\t- {key}: {value}")
print(f"Total training time: {time}")
# Out:
# Accuracy of Optimised Model: 0.8355053067207336
# Best Hyperparameters:
# 	- activation: relu
# Total training time: 4742.093411207199

# %% [markdown]
# We train the CNN model with these parameters

# %%
# Train with the best params
best_cnn = create_cnn(num_classes=len(np.unique(y_train)), **best_cnn_params)
best_cnn_history = best_cnn.fit(x_train, one_hot_y_train, epochs=10, batch_size=47, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 1920/1920 [==============================] - 30s 15ms/step - loss: 1.3437 - accuracy: 0.6175 - val_loss: 0.7202 - val_accuracy: 0.7746
# Epoch 2/10
# 1920/1920 [==============================] - 51s 27ms/step - loss: 0.6235 - accuracy: 0.8014 - val_loss: 0.5740 - val_accuracy: 0.8111
# Epoch 3/10
# 1920/1920 [==============================] - 45s 24ms/step - loss: 0.5228 - accuracy: 0.8295 - val_loss: 0.5200 - val_accuracy: 0.8299
# Epoch 4/10
# 1920/1920 [==============================] - 44s 23ms/step - loss: 0.4731 - accuracy: 0.8442 - val_loss: 0.4944 - val_accuracy: 0.8352
# Epoch 5/10
# 1920/1920 [==============================] - 44s 23ms/step - loss: 0.4395 - accuracy: 0.8535 - val_loss: 0.4656 - val_accuracy: 0.8440
# Epoch 6/10
# 1920/1920 [==============================] - 46s 24ms/step - loss: 0.4168 - accuracy: 0.8594 - val_loss: 0.4502 - val_accuracy: 0.8465
# Epoch 7/10
# 1920/1920 [==============================] - 45s 23ms/step - loss: 0.3970 - accuracy: 0.8660 - val_loss: 0.4406 - val_accuracy: 0.8495
# Epoch 8/10
# 1920/1920 [==============================] - 45s 23ms/step - loss: 0.3814 - accuracy: 0.8709 - val_loss: 0.4292 - val_accuracy: 0.8515
# Epoch 9/10
# 1920/1920 [==============================] - 48s 25ms/step - loss: 0.3688 - accuracy: 0.8742 - val_loss: 0.4286 - val_accuracy: 0.8544
# Epoch 10/10
# 1920/1920 [==============================] - 48s 25ms/step - loss: 0.3575 - accuracy: 0.8772 - val_loss: 0.4198 - val_accuracy: 0.8563

# %% [markdown]
# ## Save the CNN model

# %%
# Saving the CNN Model
best_cnn.save("cnn_model.h5", overwrite=True)

# %% [markdown]
# ## Plotting the training results

# %%
plot_loss_and_accuracy(best_cnn_history, 'CNN')

# %% [markdown]
# # Results
# ### Now that we have recieved the best of the two models, we can now evaluate these models on the testing dataset

# %%
# Load MLP and CNN models
best_mlp = load_model('mlp_model.h5')
best_cnn = load_model('cnn_model.h5')

# %% [markdown]
# We evaluate both the models to get the loss and accuracy

# %%
mlp_result = best_mlp.evaluate(x_test, one_hot_y_test)
cnn_result = best_cnn.evaluate(x_test, one_hot_y_test)
# Out:
# 588/588 [==============================] - 2s 2ms/step - loss: 0.7796 - accuracy: 0.7687
# 588/588 [==============================] - 4s 6ms/step - loss: 0.4404 - accuracy: 0.8559

# %% [markdown]
# We predict the labels of the test data set

# %%
# Make predictions using both models
mlp_pred = best_mlp.predict(x_test, verbose=1)
cnn_pred = best_cnn.predict(x_test, verbose=1)
# Out:
# 588/588 [==============================] - 1s 2ms/step
# 588/588 [==============================] - 3s 6ms/step

# %% [markdown]
# ## Predicted Results
# Let us now visualise the predicted and actual labels

# %%
def pred_images(x_test, y_test, predicted_labels, class_mapping, model, num_images=6):
    """
    Plots a specified number of images from the test set along with their true and predicted labels.

    Parameters:
        x_test (numpy.ndarray): Array of test images.
        y_test (numpy.ndarray): Array of true labels corresponding to the test images.
        predicted_labels (numpy.ndarray): Array of predicted labels for the test images.
        class_mapping (dict): A dictionary mapping label indices to their corresponding characters.
        model (str): Name or identifier of the model used for predictions, displayed as the title of the plot.
        num_images (int): Number of images to plot. Default is 5.

    Returns:
        None
    """
    # Generate indices for first 6 samples
    indices = list(range(0, 6))
    
    # Create subplots
    fig, axes = plt.subplots(1, num_images, figsize=(15, 3))
    
    # Plot each image with true and predicted labels
    for i, idx in enumerate(indices):
        ax = axes[i]
        image = x_test[idx].reshape(28, 28)  # Reshape image to 28x28
        true_label_index = y_test[idx]
        true_label = class_mapping[true_label_index]
        predicted_label_index = predicted_labels[idx]
        predicted_label = class_mapping[predicted_label_index] 
        ax.imshow(image, cmap='magma')
        fig.suptitle(model)
        # Plots the class labels and predicted labels
        ax.set_title(f"True Label: {chr(true_label)} ({true_label})\nPredicted Label: {chr(predicted_label)} ({predicted_label})")
        ax.axis('off')
    plt.tight_layout()
    plt.show()

# %%
# Converts one hot encoded predictions to class lables
mlp_pred_indices = np.argmax(mlp_pred, axis=1)
cnn_pred_indices = np.argmax(cnn_pred, axis=1)

# Plot images with true labels and model predicted labels
pred_images(x_test, y_test, mlp_pred_indices, class_mapping, model='MLP')
pred_images(x_test, y_test, cnn_pred_indices, class_mapping, model='CNN')

# %% [markdown]
# ## Summary of the results
# We now calcuate the final perfomance metrics of the two models

# %%
def plot_confusion_matrix(y_test, y_pred, title, class_mapping):
    """
    Plots a confusion matrix using ConfusionMatrixDisplay.

    Parameters:
        y_test (numpy.ndarray): True labels.
        y_pred (numpy.ndarray): Predicted labels.
        title (str): Title of the plot.
        class_mapping (dict): A dictionary mapping label indices to their corresponding characters.

    Returns:
        None
    """
    # Calculate confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Create ConfusionMatrixDisplay object
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_mapping.values())
    
    plt.figure(figsize=(30, 10))
    disp.plot(cmap='YlOrBr', ax=plt.gca())
    plt.title(title)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    
    # Convert numeric indices to ASCII characters for xticks and yticks
    xtick_labels = [chr(class_mapping[i]) for i in range(len(class_mapping))]
    ytick_labels = [chr(class_mapping[i]) for i in range(len(class_mapping))]
    
    # Plotting class labels on the ticks
    plt.xticks(ticks=range(len(class_mapping)), labels=xtick_labels, rotation=90)
    plt.yticks(ticks=range(len(class_mapping)), labels=ytick_labels)
    plt.show()

# Plot confusion matrices for MLP and CNN models with class labels
plot_confusion_matrix(y_test, mlp_pred_indices, title='MLP Confusion Matrix', class_mapping=class_mapping)
plot_confusion_matrix(y_test, cnn_pred_indices, title='CNN Confusion Matrix', class_mapping=class_mapping)

# %% [markdown]
# We calculate accuracy, precision, recall and f1-score

# %%
def calculate_metrics(model_name, y_test, y_pred):
    """
    Calculates evaluation metrics (accuracy, precision, recall, F1 score) for a given model's predictions.

    Parameters:
        model_name (str): Name or identifier of the model.
        y_test (numpy.ndarray): True labels.
        y_pred (numpy.ndarray): Predicted labels.

    Returns:
        dict: A dictionary containing the calculated metrics.
    """
    # Calculate accuracy, precision, recall and f-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    
    # Return metrics as a dictionary
    return {
        'Model': model_name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1
    }

# Calculate metrics for MLP model
mlp_metrics = calculate_metrics('MLP', y_test, mlp_pred_indices)

# Calculate metrics for CNN model
cnn_metrics = calculate_metrics('CNN', y_test, cnn_pred_indices)

# Create a DataFrame to store the metrics
metrics_df = pd.DataFrame([mlp_metrics, cnn_metrics])

# %%
metrics_df
# Out:
#   Model  Accuracy  Precision    Recall  F1 Score
# 0   MLP  0.768723   0.767785  0.768723  0.766340
# 1   CNN  0.855851   0.858535  0.855851  0.854928

# %% [markdown]
# Visualising the metrics

# %%
# Plotting the results
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(18, 5), sharey=True)
fig.suptitle("Performance Comparison")

sns.scatterplot(ax=ax1, x='Model', y='Precision', data=metrics_df, hue='Model', palette='rocket')
ax1.plot(metrics_df['Model'], metrics_df['Precision'], c='darkgrey')
ax1.set_title('Precision Graph')
ax1.set_ylabel('Metrics Score')

sns.scatterplot(ax=ax2, x='Model', y='Accuracy', data=metrics_df, hue='Model', palette='rocket')
ax2.plot(metrics_df['Model'], metrics_df['Accuracy'], c='darkgrey')
ax2.set_title('Accuracy Graph')

sns.scatterplot(ax=ax3, x='Model', y='Recall', data=metrics_df, hue='Model', palette='rocket')
ax3.plot(metrics_df['Model'], metrics_df['Recall'], c='darkgrey')
ax3.set_title('Recall Graph')

sns.scatterplot(ax=ax4, x='Model', y='F1 Score', data=metrics_df, hue='Model', palette='rocket')
ax4.plot(metrics_df['Model'], metrics_df['F1 Score'], c='darkgrey')
ax4.set_title('F1 Score Graph')

plt.legend()
plt.show()

# %% [markdown]
# ### CNN significantly outperformed MLP on the EMNIST handwritten digit task. This is because CNNs can automatically learn spatial features from images and are robust to variations, while MLPs struggle with these aspects. The superior performance of the CNN was confirmed by metrics like accuracy, precision, recall and F-score.
